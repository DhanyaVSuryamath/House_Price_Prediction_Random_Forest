# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\CHINMAYI SURYAMATH\Desktop\ML PROJECT ECOMMERCE\Final_House_Price_prediction\HousePricePrediction.xlsx")

# %%
num_cols = ['MSSubClass','LotArea','OverallCond','YearBuilt',
            'YearRemodAdd','BsmtFinSF2','TotalBsmtSF']

# Heatmap of correlations
plt.figure(figsize=(7,5))
sns.heatmap(data[num_cols + ['SalePrice']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Scatter plots for each numeric column vs SalePrice
for col in num_cols:
    plt.figure(figsize=(5,4))
    plt.scatter(data[col], data['SalePrice'], alpha=0.5)
    plt.xlabel(col)
    plt.ylabel('SalePrice')
    plt.title(f'{col} vs SalePrice')
    plt.tight_layout()
    plt.show()

# %%
cat_cols = ['MSSubClass', 'OverallCond']

for col in cat_cols:
    # 3.1 Value counts
    print(f"\n-- {col} value counts:")
    print(data[col].value_counts())

    # 3.2 Boxplot of SalePrice by category
    plt.figure(figsize=(6,4))
    sns.boxplot(x=col, y='SalePrice', data=data)
    plt.title(f'SalePrice by {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# -- MSSubClass value counts:
# MSSubClass
# 20     1079
# 60      575
# 50      287
# 120     182
# 30      139
# 70      128
# 160     128
# 80      118
# 90      109
# 190      61
# 85       48
# 75       23
# 45       18
# 180      17
# 40        6
# 150       1
# Name: count, dtype: int64
# -- OverallCond value counts:
# OverallCond
# 5    1645
# 6     531
# 7     390
# 8     144
# 4     101
# 3      50
# 9      41
# 2      10
# 1       7
# Name: count, dtype: int64
